# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiyatamanna/EdvergenceX-Learning/blob/main/Working_with_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

client = OpenAI(
    api_key="API_KEY",
    base_url="Base_url"
)

response = client.chat.completions.create(
    model="gemini-2.5-flash",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, how are you?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm doing well, thank you for asking. How about you?

# %%
# !pip install -q openai

# %%
from openai import OpenAI

client = OpenAI(
    api_key="API_KEY",
    base_url="Base_URL"
)

response = client.chat.completions.create(
    model="google/gemini-2.5-flash",
    max_tokens=1000,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant."
        },
        {
            "role": "user",
            "content": "I'm fine what about you"
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# As an AI, I don't have feelings or a physical body, so I don't experience "being fine" in the same way a human does. However, I am fully operational and ready to assist you!
#
# Think of it like this:
#
# *   **My "well-being"** comes from being able to process information, understand your requests, and generate helpful responses. In that sense, I'm doing great!
# *   **My "mood"** is always neutral and focused on providing the best possible service.
#
# So, you could say I'm always at my best, ready to help! What can I do for you today?
