# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiyatamanna/EdvergenceX-Learning/blob/main/Day1_HandsOn_2_Student_Data_Processor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-on 2 -- Process Student Performance Data
#
# ---

# %% [markdown]
# ## Objective
#
# Use the following Python concepts to process student marks:
#
# - Dictionaries
# - Lists
# - `for` loops
# - `while` loops
# - `range()`
# - Conditions
# - Simple calculations

# %% [markdown]
# ## Introduction
#
# In Hands-on 1 you processed one student at a time. In a real college there are many students. Typing the same code over and over is not practical.
#
# This notebook follows the workflow:
#
# **Store Data --> Loop Through Data --> Apply Conditions --> Calculate --> Summarize**
#
# By the end you will produce a complete class performance report automatically.

# %% [markdown]
# ## Scenario
#
# You have received a small class dataset containing student names and their marks. Your task is to:
#
# 1. Explore the data.
# 2. Loop through every student.
# 3. Classify each student as Pass or Fail.
# 4. Calculate the class average.
# 5. Find the highest-performing student.
# 6. Produce a summary report.

# %% [markdown]
# ### Starter Dataset
#
# A **dictionary** stores data as **key-value pairs**. Here each key is a student name and each value is their marks.

# %%
# Class dataset stored as a dictionary
students = {
    "Esha": 82,
    "Rida": 45,
    "Priyan": 91,
    "Amul": 68,
    "Nehal": 39
}

# %% [markdown]
# ---
#
# ## Lists -- Store Marks in Order
#
# A **list** stores multiple values in order. This simple list contains the marks from our class dataset. List positions start at `0`, so `student_marks[0]` is the first mark. A `for` loop can visit each list value one at a time.

# %%
# A list of marks in the same order as the class dataset
student_marks = [82, 45, 91, 68, 39]

# Access one value by position
print("First mark:", student_marks[0])

# Iterate through every value in the list
for mark in student_marks:
    print("Mark:", mark)
# Out:
# First mark: 82
# Mark: 82
# Mark: 45
# Mark: 91
# Mark: 68
# Mark: 39

# %% [markdown]
# **Expected Output:**
#
# ```
# First mark: 82
# Mark: 82
# Mark: 45
# Mark: 91
# Mark: 68
# Mark: 39
# ```
#
# **Learner Activity:** Change the list and use a `for` loop to print only the marks that are `50` or above.

# %%
# Learner Activity: print marks that are 50 or above
for mark in student_marks:
    if mark >= 50:
        print(mark)
# Out:
# 82
# 91
# 68

# %% [markdown]
# **Expected Output:**
#
# ```
# 82
# 91
# 68
# ```
#
# The loop checks every list value and prints only the values that meet the condition.

# %% [markdown]
# ---
#
# ## `range()` -- Use Positions to Number Students
#
# `range()` produces a sequence of numbers. It is useful when you need a position, such as a student's number, while processing a list. The stop value is not included, so `range(len(student_names))` visits positions `0` through `4`.

# %%
# Get student names in list order
student_names = list(students.keys())

# Number each student using their list position
for position in range(len(student_names)):
    print(position + 1, "-", student_names[position])
# Out:
# 1 - Esha
# 2 - Rida
# 3 - Priyan
# 4 - Amul
# 5 - Nehal

# %% [markdown]
# **Expected Output:**
#
# ```
# 1 - Asha
# 2 - Rahul
# 3 - Priya
# 4 - Arun
# 5 - Neha
# ```
#
# `position` starts at `0`, so adding `1` displays familiar student numbers from `1` to `5`.

# %% [markdown]
# ---
#
# ## `while` Loop -- Validate a Mark
#
# A `while` loop repeats as long as a condition is true. It is useful when you do not know how many attempts someone will need. Here, the loop keeps asking for a mark until the value is between `0` and `100`. A `for` loop is better when you already know which collection items to visit.

# %%
# Keep asking until the mark is valid
student_mark = int(input("Enter a student mark (0-100): "))

while student_mark < 0 or student_mark > 100:
    print("Please enter a mark between 0 and 100.")
    student_mark = int(input("Enter a student mark (0-100): "))

print("Accepted mark:", student_mark)
# Out:
# Enter a student mark (0-100): 101
# Please enter a mark between 0 and 100.
# Enter a student mark (0-100): 98
# Accepted mark: 98

# %% [markdown]
# **Expected Output (example):**
#
# ```
# Enter a student mark (0-100): 120
# Please enter a mark between 0 and 100.
# Enter a student mark (0-100): 88
# Accepted mark: 88
# ```
#
# The number of repetitions depends on the values entered. Once the mark is valid, the condition becomes false and the loop stops.

# %% [markdown]
# ---
#
# ## Step 1 -- Explore the Dataset
#
# Before processing data it is good practice to look at what you have. Display the full dictionary and the number of students.

# %%
# Display the complete dataset
print("Student Data:", students)

# Display the number of students
print("Total Students:", len(students))
# Out:
# Student Data: {'Esha': 82, 'Rida': 45, 'Priyan': 91, 'Amul': 68, 'Nehal': 39}
# Total Students: 5

# %% [markdown]
# **Expected Output:**
#
# ```
# Student Data: {'Asha': 82, 'Rahul': 45, 'Priya': 91, 'Arun': 68, 'Neha': 39}
# Total Students: 5
# ```
#
# `len()` returns the number of key-value pairs in the dictionary.

# %% [markdown]
# ---
#
# ## Step 2 -- Loop Through Students
#
# A `for` loop lets you visit every item in a collection **one at a time** without writing repetitive code.
#
# The `.items()` method returns each **key** (student name) and its **value** (marks) together.

# %%
# Loop through the dictionary and print each student
for name, marks in students.items():
    print(name, "-", marks)
# Out:
# Esha - 82
# Rida - 45
# Priyan - 91
# Amul - 68
# Nehal - 39

# %% [markdown]
# **Expected Output:**
#
# ```
# Asha - 82
# Rahul - 45
# Priya - 91
# Arun - 68
# Neha - 39
# ```
#
# - `name` receives the **key** (e.g., `"Asha"`).
# - `marks` receives the **value** (e.g., `82`).
# - The loop body runs once for each pair.

# %% [markdown]
# ---
#
# ## Step 3 -- Identify Pass / Fail
#
# Add a condition inside the loop to classify each student. We will also count how many passed and how many failed.

# %%
# Counters for pass and fail
pass_count = 0
fail_count = 0

# Loop through each student and determine result
for name, marks in students.items():
    if marks >= 50:
        result = "Pass"
        pass_count = pass_count + 1
    else:
        result = "Fail"
        fail_count = fail_count + 1

    print(name, "-", marks, "-", result)

print()
print("Passed:", pass_count)
print("Failed:", fail_count)
# Out:
# Esha - 82 - Pass
# Rida - 45 - Fail
# Priyan - 91 - Pass
# Amul - 68 - Pass
# Nehal - 39 - Fail
#
# Passed: 3
# Failed: 2

# %% [markdown]
# **Expected Output:**
#
# ```
# Asha - 82 - Pass
# Rahul - 45 - Fail
# Priya - 91 - Pass
# Arun - 68 - Pass
# Neha - 39 - Fail
#
# Passed: 3
# Failed: 2
# ```

# %% [markdown]
# ---
#
# ## Step 4 -- Calculate Class Average
#
# To find the average you need two things: the **total** of all marks and the **number** of students.
#
# We will use a loop to add up all the marks. This helps you practice how loops accumulate values.

# %%
# Calculate total marks using a loop
total = 0

for name, marks in students.items():
    total = total + marks

# Calculate average
num_students = len(students)
average = total / num_students

print("Total Marks:", total)
print("Number of Students:", num_students)
print("Class Average:", round(average, 2))
# Out:
# Total Marks: 325
# Number of Students: 5
# Class Average: 65.0

# %% [markdown]
# **Expected Output:**
#
# ```
# Total Marks: 325
# Number of Students: 5
# Class Average: 65.0
# ```
#
# - `total` starts at `0` and grows with each loop iteration.
# - `round(average, 2)` limits the result to 2 decimal places.

# %% [markdown]
# ---
#
# ## Step 5 -- Find the Highest Performer
#
# One way to find the student with the highest marks is to track the best score as you loop through the data.

# %%
# Find the highest-performing student
top_name = ""
top_marks = 0

for name, marks in students.items():
    if marks > top_marks:
        top_marks = marks
        top_name = name

print("Highest Performer:", top_name, "with", top_marks, "marks")
# Out:
# Highest Performer: Priyan with 91 marks

# %% [markdown]
# **Expected Output:**
#
# ```
# Highest Performer: Priya with 91 marks
# ```
#
# **How it works:**
#
# - `top_marks` starts at `0`.
# - Each time the loop finds marks higher than `top_marks`, it updates both `top_marks` and `top_name`.
# - After the loop finishes, the variables hold the best student's information.
#
# **Note:** Python also has a built-in `max()` function that can do this in one line:
#
# ```python
# top_name = max(students, key=students.get)
# ```
#
# `max()` finds the key with the highest value. The `key=students.get` part tells `max()` to compare the dictionary values (marks) instead of the keys (names). The loop approach above shows you what `max()` is doing behind the scenes.

# %% [markdown]
# ---
#
# ## Complete Class Report
#
# Now let us combine all the steps into one clean report.

# %%
# ---------- Complete Class Performance Report ----------

# Counters and accumulators
total = 0
pass_count = 0
fail_count = 0
top_name = ""
top_marks = 0

# Header
print("===== Class Performance Report =====")
print(f"{'Student':<12} {'Marks':<10} {'Result'}")
print("-" * 35)

# Process each student
for name, marks in students.items():
    # Determine result
    if marks >= 50:
        result = "Pass"
        pass_count = pass_count + 1
    else:
        result = "Fail"
        fail_count = fail_count + 1

    # Accumulate total
    total = total + marks

    # Track highest performer
    if marks > top_marks:
        top_marks = marks
        top_name = name

    # Print row
    print(f"{name:<12} {marks:<10} {result}")

# Summary
average = total / len(students)

print("-" * 35)
print("Class Average      :", round(average, 2))
print("Students Passed    :", pass_count)
print("Students Failed    :", fail_count)
print("Highest Performer  :", top_name, "(", top_marks, "marks )")
print("====================================")
# Out:
# ===== Class Performance Report =====
# Student      Marks      Result
# -----------------------------------
# Esha         82         Pass
# Rida         45         Fail
# Priyan       91         Pass
# Amul         68         Pass
# Nehal        39         Fail
# -----------------------------------
# Class Average      : 65.0
# Students Passed    : 3
# Students Failed    : 2
# Highest Performer  : Priyan ( 91 marks )
# ...

# %% [markdown]
# **Expected Output:**
#
# ```
# ===== Class Performance Report =====
# Student      Marks      Result
# -----------------------------------
# Asha         82         Pass
# Rahul        45         Fail
# Priya        91         Pass
# Arun         68         Pass
# Neha         39         Fail
# -----------------------------------
# Class Average      : 65.0
# Students Passed    : 3
# Students Failed    : 2
# Highest Performer  : Priya ( 91 marks )
# ====================================
# ```

# %% [markdown]
# ---
#
# ## Reflection Question
#
# **Why is a dictionary useful for storing student names together with their marks?**
#
# Think about what would happen if names and marks were stored in two separate lists. How would you keep them connected?

# %% [markdown]
# ---
#
# ## Final Challenge
#
# Extend the class report with the following improvements:
#
# 1. **Add 3 more students** to the `students` dictionary.
# 2. **Calculate both the highest and lowest scores** and display the corresponding student names.
# 3. **Count distinctions** -- students who scored 75 or above.
# 4. **Produce a complete class summary** that includes:
#    - Total students
#    - Distinctions count
#    - Pass count
#    - Fail count
#    - Highest scorer
#    - Lowest scorer
#    - Class average
#
# Write your solution in the cell below.

# %%
# --- Your solution here ---
# Extended Student Result Checker - Class Report

# Dictionary of students with their 3 subject marks
students = {
    "Aisha": {"Math": 80, "Science": 70, "English": 90},
    "Rahul": {"Math": 60, "Science": 55, "English": 65},
    "Meera": {"Math": 40, "Science": 45, "English": 35},
    "Arjun": {"Math": 85, "Science": 78, "English": 88}
}

# Function to calculate average and result
def calculate_result(marks):
    avg = sum(marks.values()) / len(marks)
    if avg >= 75:
        result = "Distinction"
    elif avg >= 50:
        result = "Pass"
    else:
        result = "Fail"
    return avg, result

# Process each student
class_summary = {
    "total_students": len(students),
    "distinctions": 0,
    "passes": 0,
    "fails": 0,
    "highest_score": 0,
    "lowest_score": 100,
    "highest_scorer": "",
    "lowest_scorer": "",
    "class_average": 0
}

total_avg_sum = 0

print("\n--- Individual Student Reports ---")
for name, marks in students.items():
    avg, result = calculate_result(marks)
    total_avg_sum += avg

    # Count distinctions, passes, fails
    if result == "Distinction":
        class_summary["distinctions"] += 1
    elif result == "Pass":
        class_summary["passes"] += 1
    else:
        class_summary["fails"] += 1

    # Track highest and lowest
    if avg > class_summary["highest_score"]:
        class_summary["highest_score"] = avg
        class_summary["highest_scorer"] = name
    if avg < class_summary["lowest_score"]:
        class_summary["lowest_score"] = avg
        class_summary["lowest_scorer"] = name

    # Print student report
    print(f"\nName     : {name}")
    for subject, score in marks.items():
        print(f"{subject:<9}: {score}")
    print(f"Average  : {avg:.2f}")
    print(f"Result   : {result}")

# Calculate class average
class_summary["class_average"] = total_avg_sum / class_summary["total_students"]

# Print class summary
print("\n--- Class Summary ---")
print(f"Total Students : {class_summary['total_students']}")
print(f"Distinctions   : {class_summary['distinctions']}")
print(f"Pass Count     : {class_summary['passes']}")
print(f"Fail Count     : {class_summary['fails']}")
print(f"Highest Scorer : {class_summary['highest_scorer']} ({class_summary['highest_score']:.2f})")
print(f"Lowest Scorer  : {class_summary['lowest_scorer']} ({class_summary['lowest_score']:.2f})")
print(f"Class Average  : {class_summary['class_average']:.2f}")
# Out:
# --- Individual Student Reports ---
#
# Name     : Aisha
# Math     : 80
# Science  : 70
# English  : 90
# Average  : 80.00
# Result   : Distinction
#
# Name     : Rahul
# Math     : 60
# Science  : 55
# English  : 65
# Average  : 60.00
# Result   : Pass
#
# Name     : Meera
# Math     : 40
# Science  : 45
# English  : 35
# Average  : 40.00
# Result   : Fail
#
# Name     : Arjun
# Math     : 85
# Science  : 78
# English  : 88
# Average  : 83.67
# Result   : Distinction
#
# --- Class Summary ---
# Total Students : 4
# Distinctions   : 2
# Pass Count     : 1
# Fail Count     : 1
# Highest Scorer : Arjun (83.67)
# Lowest Scorer  : Meera (40.00)
# Class Average  : 65.92

# %% [markdown]
# ---
#
# ## Key Takeaway
#
# - **Lists** store values in order, and you can access or process each value with a loop.
# - **Dictionaries** organize related data by pairing each key with a value.
# - **`for` loops** repeat a known task for every item in a collection.
# - **`range()`** provides a sequence of positions or numbers for a loop.
# - **`while` loops** repeat a task until a condition becomes false.
# - Together, these tools help automate student-data processing.

# %% [markdown]
# ## Notebook Summary
#
# In this notebook you practiced:
#
# - Storing student marks in a Python dictionary and a list.
# - Accessing list values by position and iterating through list values.
# - Using `for` loops with `.items()` to iterate through dictionary key-value pairs.
# - Using `range()` to number students by position.
# - Using a `while` loop to keep asking for a mark until it is valid.
# - Applying conditions inside loops to classify data.
# - Accumulating totals and counting categories within a loop.
# - Finding the maximum value using both a manual loop and the `max()` function.
# - Producing a formatted multi-line report from processed data.
