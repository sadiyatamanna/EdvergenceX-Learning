# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiyatamanna/EdvergenceX-Learning/blob/main/CrewAI_Multi_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install crewai[tools] -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.4/202.4 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.4/841.4 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.6/222.6 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 92.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 71.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 36.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.4/591.4 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.2/353.2 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.8/406.8 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 85.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 58.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.4/731.4 kB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 65.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.2/485.2 kB 18.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# bigframes 2.48.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
from crewai import LLM, Agent, Task, Crew

# %%
from google.colab import userdata
api_key=userdata.get('api_key')

# %%
llm=LLM(model="gpt-4.1-nano",
        temperature=0.7,
        base_url="https://nexusapi.navigatelabs.ai",
        api_key=api_key)

# %%
research_agent = Agent(
    role="Data Analyst",
    goal="Extract the most important facts about a given AI topic",
    backstory="An expert in data who breaks down topics into core components for summarization.",
    tools=[],
    llm=llm,
    verbose=True
)

# Summary Generator Agent
summarizer_agent = Agent(
    role="Summary Generator",
    goal="Write clear, structured summaries based on researched content",
    backstory="An assistant skilled at creating exam-ready indexed summaries from detailed content.",
    tools=[],
    llm=llm,
    verbose=True
)

# Summary Tester Agent
tester_agent = Agent(
    role="Summary Tester",
    goal="Verify and improve the summary for clarity, structure, and exam effectiveness",
    backstory="An expert reviewer who checks AI summaries for completeness, accuracy, and readability.",
    tools=[],
    llm=llm,
    verbose=True
)

# %%
topic = input("Enter the AI topic you want summarized: ")
# Out:
# Enter the AI topic you want summarized: Data Analysis

# %%
research_task = Task(
    description=f"Research and extract the key concepts, definitions, and examples for the topic: '{topic}'",
    expected_output="A structured research note covering key concepts, definitions, and any relevant subtopics.",
    agent=research_agent
)

# Task 2: Create summary from research
summary_task = Task(
    description="Using the research notes, generate a concise exam-style summary with 5–7 indexed bullet points.",
    expected_output="A summary in the format: 1. ..., 2. ..., 3. ..., covering all important points clearly.",
    agent=summarizer_agent,
    context=[research_task]
)

# Task 3: Review and enhance the summary
testing_task = Task(
    description="Review the generated summary for structure, clarity, and completeness. Suggest or apply improvements if needed.",
    expected_output="A final polished summary that’s accurate, easy to read, and suitable for AI exam preparation.",
    agent=tester_agent,
    context=[summary_task]
)

# %%
import asyncio

crew=Crew(tasks=[research_task,summary_task,testing_task])
result=await crew.kickoff_async()
print("Final Reviewed summary", result)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Analyst                                                                                            │
# │                                                                                                                 │
# │  Task: Research and extract the key concepts, definitions, and examples for the topic: 'Data Analysis'          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Data Analyst                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Data Analysis: Key Concepts, Definitions, and Subtopics**                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **1. Definition of Data Analysis**                                                                         │
# │  Data analysis is the process of systematically applying statistical and logical techniques to describe,        │
# │  summarize, and evaluate data. It involves inspecting, cleaning, transforming, and modeling data with the goal  │
# │  of discovering useful information, drawing conclusions, and supporting decision-making.                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **2. Core Concepts in Data Analysis**                                                                      │
# │                                                                                                                 │
# │  - **Data Collection:** Gathering relevant data from various sources such as databases, surveys, sensors, or    │
# │  external datasets.                                                                                             │
# │  - **Data Cleaning:** Removing inaccuracies, handling missing values, correcting errors, and ensuring data      │
# │  quality.                                                                                                       │
# │  - **Data Transformation:** Converting data into appropriate formats or structures for analysis, including      │
# │  normalization, encoding categorical variables, or aggregating data.                                            │
# │  - **Exploratory Data Analysis (EDA):** An initial step involving visual and statistical methods to understand  │
# │  data distributions, relationships, and patterns.                                                               │
# │  - **Statistical Analysis:** Applying statistical tests and models to infer properties about the data or test   │
# │  hypotheses.                                                                                                    │
# │  - **Data Visualization:** Using charts, graphs, and plots to represent data insights visually, facilitating    │
# │  easier interpretation.                                                                                         │
# │  - **Modeling & Predictive Analytics:** Employing algorithms to model data and predict future trends or         │
# │  classify data points.                                                                                          │
# │  - **Interpretation & Reporting:** Summarizing findings in reports or dashboards to inform stakeholders.        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **3. Definitions of Key Terms**                                                                            │
# │                                                                                                                 │
# │  - **Descriptive Analysis:** Summarizes data to describe its main features, such as measures of central         │
# │  tendency (mean, median) and dispersion (variance, standard deviation).                                         │
# │  - **Inferential Analysis:** Uses a sample of data to make generalizations or predictions about a larger        │
# │  population.                                                                                                    │
# │  - **Predictive Analysis:** Utilizes statistical models and machine learning techniques to forecast future      │
# │  outcomes based on historical data.                                                                             │
# │  - **Prescriptive Analysis:** Recommends actions based on data insights, often involving optimization           │
# │  techniques.                                                                                                    │
# │  - **Big Data:** Extremely large datasets that require advanced tools and methods to process and analyze        │
# │  efficiently.                                                                                                   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **4. Common Techniques & Methods**                                                                         │
# │                                                                                                                 │
# │  - **Statistical Methods:** Regression analysis, hypothesis testing, correlation analysis, ANOVA.               │
# │  - **Machine Learning Algorithms:** Classification, clustering, decision trees, neural networks, support        │
# │  vector machines.                                                                                               │
# │  - **Data Visualization Tools:** Tableau, Power BI, matplotlib, seaborn.                                        │
# │  - **Data Mining:** Extracting patterns and knowledge from large datasets using algorithms like association     │
# │  rule mining and clustering.                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **5. Examples of Data Analysis Applications**                                                              │
# │                                                                                                                 │
# │  - **Business:** Customer segmentation, sales trend analysis, market basket analysis.                           │
# │  - **Healthcare:** Patient outcome prediction, disease outbreak tracking, medical image analysis.               │
# │  - **Finance:** Fraud detection, risk assessment, stock price prediction.                                       │
# │  - **Social Media:** Sentiment analysis, trend detection, user behavior analysis.                               │
# │  - **Manufacturing:** Quality control, predictive maintenance, supply chain optimization.                       │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **6. Subtopics in Data Analysis**                                                                          │
# │                                                                                                                 │
# │  - **Qualitative vs. Quantitative Data Analysis:** Qualitative involves non-numerical data (interviews, text),  │
# │  while quantitative deals with numerical data.                                                                  │
# │  - **Descriptive vs. Inferential vs. Predictive vs. Prescriptive Analytics:** Different levels and purposes of  │
# │  analysis.                                                                                                      │
# │  - **Automated Data Analysis:** Use of AI and machine learning to automate insights generation.                 │
# │  - **Data Privacy and Ethics:** Ensuring data is handled responsibly, respecting privacy laws such as GDPR.     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **7. Tools & Software for Data Analysis**                                                                  │
# │  - **Excel:** Basic data analysis and visualization.                                                            │
# │  - **Python:** Libraries like pandas, NumPy, scikit-learn, matplotlib for advanced analysis.                    │
# │  - **R:** Statistical computing and graphics.                                                                   │
# │  - **SQL:** Data querying and management.                                                                       │
# │  - **Business Intelligence Tools:** Tableau, Power BI, QlikView.                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Summary**                                                                                                │
# │  Data analysis is a multi-faceted discipline essential for extracting actionable insights from data through a   │
# │  combination of statistical, mathematical, and computational techniques. It supports decision-making across     │
# │  diverse fields by transforming raw data into meaningful information.                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **End of Complete Research Note**                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Summary Generator                                                                                       │
# │                                                                                                                 │
# │  Task: Using the research notes, generate a concise exam-style summary with 5–7 indexed bullet points.          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Summary Generator                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  1. Data analysis is the systematic application of statistical and logical techniques to describe, summarize,   │
# │  and evaluate data, aiming to uncover useful information and support decision-making.                           │
# │  2. Core components of data analysis include data collection, cleaning, transformation, exploratory data        │
# │  analysis (EDA), statistical analysis, visualization, modeling, and reporting.                                  │
# │  3. Key terms in data analysis encompass descriptive analysis (summarizing data), inferential analysis (making  │
# │  population inferences), predictive analysis (forecasting future trends), prescriptive analysis (recommending   │
# │  actions), and the concept of big data requiring advanced tools.                                                │
# │  4. Common techniques involve statistical methods such as regression and hypothesis testing, machine learning   │
# │  algorithms like classification and clustering, data visualization tools (e.g., Tableau, matplotlib), and data  │
# │  mining for pattern extraction.                                                                                 │
# │  5. Data analysis applications span various fields, including business (customer segmentation), healthcare      │
# │  (disease tracking), finance (fraud detection), social media (sentiment analysis), and manufacturing            │
# │  (predictive maintenance).                                                                                      │
# │  6. Subtopics include qualitative vs. quantitative analysis, the different levels of analytics (descriptive,    │
# │  inferential, predictive, prescriptive), automation via AI, and considerations of data privacy and ethics.      │
# │  7. Essential tools and software for data analysis are Excel, Python (with libraries such as pandas and         │
# │  scikit-learn), R, SQL, and business intelligence platforms like Tableau and Power BI.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Summary Tester                                                                                          │
# │                                                                                                                 │
# │  Task: Review the generated summary for structure, clarity, and completeness. Suggest or apply improvements if  │
# │  needed.                                                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Summary Tester                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Data analysis is the systematic process of applying statistical and logical techniques to describe,            │
# │  summarize, and evaluate data with the goal of uncovering useful information and supporting informed            │
# │  decision-making. The core components of data analysis include data collection, cleaning, transformation,       │
# │  exploratory data analysis (EDA), statistical analysis, visualization, modeling, and reporting. Key terms in    │
# │  this field encompass descriptive analysis (which summarizes data), inferential analysis (which makes           │
# │  inferences about populations), predictive analysis (forecasting future trends), and prescriptive analysis      │
# │  (recommending actions). The concept of big data refers to datasets so large and complex that they require      │
# │  advanced tools and techniques to analyze effectively.                                                          │
# │                                                                                                                 │
# │  Common techniques used in data analysis involve statistical methods such as regression analysis and            │
# │  hypothesis testing, machine learning algorithms like classification and clustering, data visualization tools   │
# │  (e.g., Tableau, matplotlib), and data mining for pattern discovery. Applications of data analysis are          │
# │  widespread across various fields, including business (customer segmentation), healthcare (disease tracking),   │
# │  finance (fraud detection), social media (sentiment analysis), and manufacturing (predictive maintenance).      │
# │                                                                                                                 │
# │  Subtopics within data analysis include the distinction between qualitative and quantitative analysis,          │
# │  different levels of analytics—descriptive, inferential, predictive, and prescriptive—and the increasing role   │
# │  of automation through artificial intelligence (AI). Additionally, considerations of data privacy and ethics    │
# │  are important when handling sensitive information.                                                             │
# │                                                                                                                 │
# │  Essential tools and software for conducting data analysis include spreadsheet programs like Excel,             │
# │  programming languages such as Python (with libraries like pandas and scikit-learn) and R, SQL for database     │
# │  management, and business intelligence platforms like Tableau and Power BI. Understanding these components,     │
# │  techniques, applications, and tools is fundamental for effective data analysis and decision-making.            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Final Reviewed summary Data analysis is the systematic process of applying statistical and logical techniques to describe, summarize, and evaluate data with the goal of uncovering useful information and supporting informed decision-making. The core components of data analysis include data collection, cleaning, transformation, exploratory data analysis (EDA), statistical analysis, visualization, modeling, and reporting. Key terms in this field encompass descriptive analysis (which summarizes data), inferential analysis (which makes inferences about populations), predictive analysis (forecasting future trends), and prescriptive analysis (recommending actions). The concept of big data refers to datasets so large and complex that they require advanced tools and techniques to analyze effectively.
#
# Common techniques used in data analysis involve statistical methods such as regression analysis and hypothesis testing, machine learning algorithms like classification and clustering, data visualization tools (e.g., Tableau, matplotlib), and data mining for pattern discovery. Applications of data analysis are widespread across various fields, including business (customer segmentation), healthcare (disease tracking), finance (fraud detection), social media (sentiment analysis), and manufacturing (predictive maintenance).
#
# Subtopics within data analysis include the distinction between qualitative and quantitative analysis, different levels of analytics—descriptive, inferential, predictive, and prescriptive—and the increasing role of automation through artificial intelligence (AI). Additionally, considerations of data privacy and ethics are important when handling sensitive information.
#
# Essential tools and software for conducting data analysis include spreadsheet programs like Excel, programming languages such as Python (with libraries like pandas and scikit-learn) and R, SQL for database management, and business intelligence platforms like Tableau and Power BI. Understanding these components, techniques, applications, and tools is fundamental for effective data analysis and decision-making.
