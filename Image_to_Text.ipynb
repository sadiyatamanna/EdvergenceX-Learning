# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiyatamanna/EdvergenceX-Learning/blob/main/Image_to_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai pillow

# %%
from google.colab import userdata, files
from PIL import Image
import base64
from io import BytesIO
import openai

# %%
# -----------------------------
# API Configuration
# -----------------------------
api_key = userdata.get("api_key")

client = openai.OpenAI(
    api_key=api_key,
    base_url="https:......"
)

# %%
# -----------------------------
# Upload Image
# -----------------------------
uploaded = files.upload()

image_path = list(uploaded.keys())[0]

# Display the uploaded image
img = Image.open(image_path)
display(img)
# Out:
#      <input type="file" id="files-7c9789c7-79c1-49de-8f83-79552e309a07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c9789c7-79c1-49de-8f83-79552e309a07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# -----------------------------
# Ask user for a question
# -----------------------------
question = input("Ask a question about the uploaded image: ")

# -----------------------------
# Convert image to Base64
# -----------------------------
with open(image_path, "rb") as f:
    image_base64 = base64.b64encode(f.read()).decode("utf-8")
# Out:
# Ask a question about the uploaded image: Describe this image

# %%
# -----------------------------
# Send Image + Text to Model
# -----------------------------
response = client.chat.completions.create(
    model="nano-banana",   # Use your vision-capable model
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": question
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{image_base64}"
                    }
                }
            ]
        }
    ]
)

print("\nModel Response:\n")
print(response.choices[0].message.content)
# Out:
# Model Response:
#
# This is an anime-style illustration of a male character, likely from a fantasy or action series, depicted in a fiery and intense setting.
#
# The character has striking red hair, styled with long, flowing locks that seem to emanate a fiery aura. His eyes glow intensely red, matching the overall color scheme. He has a serious, determined expression, and there are intricate red markings on his forehead.
#
# He is wearing traditional Japanese attire, specifically a red haori over a yellow kimono, with a black undergarment visible. His hands are positioned as if he is holding a katana, and the blade itself is glowing a vibrant red, suggesting it's imbued with a special power, possibly fire-related.
#
# ...
